# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style='darkgrid')

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 1000)

# %%
data_excel = pd.read_excel('SW_data/environment.xlsx', parse_dates=True)
data_excel.head()
# Out:
#              ISIN       Date  Quote
# 0  SLFXFSI2 Index 1996-01-05 -0.459
# 1  SLFXFSI2 Index 1996-01-12 -0.197
# 2  SLFXFSI2 Index 1996-01-19 -0.190
# 3  SLFXFSI2 Index 1996-01-26 -0.412
# 4  SLFXFSI2 Index 1996-02-02 -0.404

# %%
tickers = list(data_excel.ISIN.unique())
print('Tickers : \n')
print('\n'.join(map(str, tickers)))
# Out:
# Tickers :
#
# SLFXFSI2 Index
# VIX Index
# BICLB10Y Index
# SPXT Index

# %%
data = data_excel.pivot(columns='ISIN', index='Date').fillna(method='ffill', limit=7).dropna()
data.columns = data.columns.droplevel()
data = data.drop(columns=['BICLB10Y Index'])
data.columns = ['Stress', 'SP500', 'VIX']
data.index.name = 'Date'
data.columns.name = None
data.head(5)
# Out:
#             Stress   SP500    VIX
# Date
# 1996-01-05  -0.459  793.20  13.58
# 1996-01-08  -0.459  795.68  13.11
# 1996-01-09  -0.459  784.16  15.21
# 1996-01-10  -0.459  770.11  16.40
# 1996-01-11  -0.459  775.56  14.69
# 1996-01-12  -0.197  774.43  14.23
# 1996-01-15  -0.197  771.87  14.99
# 1996-01-16  -0.197  782.97  14.09
# 1996-01-17  -0.197  780.37  14.25
# 1996-01-18  -0.197  782.85  13.58

# %%
spread_excel = pd.read_excel('SW_data/spread.xlsx', parse_dates=True, index_col=1).drop(columns=['ISIN'])
spread_excel = spread_excel.reindex(data.index, method='ffill')
spread_excel.head()
# Out:
#             Quote
# Date
# 1996-01-05   3.84
# 1996-01-08   3.84
# 1996-01-09   3.84
# 1996-01-10   3.84
# 1996-01-11   3.84

# %%
data['Spread'] = spread_excel.values
data.head()
# Out:
#             Stress   SP500    VIX  Spread
# Date
# 1996-01-05  -0.459  793.20  13.58    3.84
# 1996-01-08  -0.459  795.68  13.11    3.84
# 1996-01-09  -0.459  784.16  15.21    3.84
# 1996-01-10  -0.459  770.11  16.40    3.84
# 1996-01-11  -0.459  775.56  14.69    3.84

# %%
data_stress = data_excel[data_excel.ISIN == 'SLFXFSI2 Index']
data_stress.index = data_stress.Date
data_stress = data_stress[['Quote']]
data_stress = data_stress.shift(1)
data_stress = data_stress.reindex(data.index, method='ffill')
data.Stress = data_stress.values
data.head(10)
# Out:
#             Stress   SP500    VIX  Spread
# Date
# 1996-01-05     NaN  793.20  13.58    3.84
# 1996-01-08     NaN  795.68  13.11    3.84
# 1996-01-09     NaN  784.16  15.21    3.84
# 1996-01-10     NaN  770.11  16.40    3.84
# 1996-01-11     NaN  775.56  14.69    3.84
# 1996-01-12  -0.459  774.43  14.23    3.84
# 1996-01-15  -0.459  771.87  14.99    3.84
# 1996-01-16  -0.459  782.97  14.09    3.84
# 1996-01-17  -0.459  780.37  14.25    3.84
# 1996-01-18  -0.459  782.85  13.58    3.84

# %%
fig, axs = plt.subplots(4, 1, figsize=(12,14), sharex=True)
data.SP500.rolling(15).mean().plot(ax=axs[0], label='SP500')
axs[0].set_title('SP 500', fontweight='bold')
axs[0].grid(b=True)

data.Stress.rolling(15).mean().plot(ax=axs[1])
axs[1].set_title('St-Louis Financial Stress Index', fontweight='bold')
axs[1].axhline(y=0.2, linestyle='-.', c='r', lw=0.8)
axs[1].grid(b=True)

data.Spread.rolling(15).mean().plot(ax=axs[2])
axs[2].set_title('HY Spread', fontweight='bold')
axs[2].axhline(y=6, linestyle='-.', c='r', lw=0.8)
axs[2].grid(b=True)

data.VIX.rolling(15).mean().plot(ax=axs[3])
axs[3].set_title('VIX', fontweight='bold')
axs[3].grid(b=True)

plt.show()

# %%
### Stratégie de base

df = pd.DataFrame(index=data.index)
df['stress'] = data.Stress
# Premiere pente
df['dx100'] = df.stress.rolling(200).apply(lambda x: (x[-1] - x[0]) / len(x))
# Deuxieme pente
df['ddx100'] = df.dx100.rolling(100).apply(lambda x: (x[-1] - x[0]) / len(x))
# 1 si premiere pente positive, 0 sinon
df['signal_dx'] = (df.dx100 > 0).astype(int)

for idx in df.index:
    iloc = df.index.get_loc(idx)
    
    # 1 si moyenne des 15 derniers jours > 0.2
    if (df.stress.iloc[iloc - 15:iloc].mean() > 0.2):
        df.at[idx, 'signal_stress'] = 1
    # -1 si moyenne des 15 derniers jours < 0
    elif (df.stress.iloc[iloc - 15:iloc].mean() < -0):
        df.at[idx, 'signal_stress'] = -1
    else:
        df.at[idx, 'signal_stress'] = 0
    
    # signal final: stress > 0.2, et pente positive => 1
    if (df.signal_stress.loc[idx] == 1) & (df.signal_dx.loc[idx] == 1):
        df.at[idx, 'signal'] = 1
    elif (df.signal_stress.loc[idx] == -1):
        df.at[idx, 'signal'] = -1
    else:
        df.at[idx, 'signal'] = 0

# 50% du return de l'indice quand Stress, 150% quand Non Stress, et 100% sinon
df['weight'] = df.signal.replace({0: 1, 1: 0.5, -1: 1.5})

df['strategie'] = df.weight * data.SP500.pct_change()
df.head(20)
# Out:
#             stress  dx100  ddx100  signal_dx  signal_stress  signal  weight  \
# Date
# 1996-01-05     NaN    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-08     NaN    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-09     NaN    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-10     NaN    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-11     NaN    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-12  -0.459    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-15  -0.459    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-16  -0.459    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-17  -0.459    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-18  -0.459    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-19  -0.197    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-22  -0.197    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-23  -0.197    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-24  -0.197    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-25  -0.197    NaN     NaN          0            0.0     0.0     1.0
# 1996-01-26  -0.190    NaN     NaN          0           -1.0    -1.0     1.5
# 1996-01-29  -0.190    NaN     NaN          0           -1.0    -1.0     1.5
# 1996-01-30  -0.190    NaN     NaN          0           -1.0    -1.0     1.5
# 1996-01-31  -0.190    NaN     NaN          0           -1.0    -1.0     1.5
# 1996-02-01  -0.190    NaN     NaN          0           -1.0    -1.0     1.5
#
#             strategie
# Date
# 1996-01-05        NaN
# 1996-01-08   0.003127
# 1996-01-09  -0.014478
# 1996-01-10  -0.017917
# 1996-01-11   0.007077
# 1996-01-12  -0.001457
# 1996-01-15  -0.003306
# 1996-01-16   0.014381
# 1996-01-17  -0.003321
# 1996-01-18   0.003178
# 1996-01-19   0.005914
# 1996-01-22   0.002565
# 1996-01-23  -0.000988
# 1996-01-24   0.011741
# 1996-01-25  -0.004712
# 1996-01-26   0.011162
# 1996-01-29   0.006580
# 1996-01-30   0.014297
# 1996-01-31   0.014236
# 1996-02-01   0.006044

# %%
# plot
fig, ax = plt.subplots(figsize=(12,6))

sns.lineplot(data=np.log((1 + df.strategie).cumprod().rolling(20).mean()), label='strategie')
sns.lineplot(data=np.log((1 + data.SP500.pct_change()).cumprod().rolling(20).mean()), label='benchmark')

for idx in df.index:
    iloc = df.index.get_loc(idx)
    if (df.signal.loc[idx] == 1):
        ax.axvline(x=idx, lw=0.4, alpha=0.15, zorder=1, c='r')
    if (df.signal.loc[idx] == -1):
        ax.axvline(x=idx, lw=0.4, alpha=0.15, zorder=1, c='g')
        
plt.xlabel(None)
plt.legend(loc='upper left')
plt.show()
