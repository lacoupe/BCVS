# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
sns.set_theme(style='darkgrid')

# %%
from data import get_price_data
from backtest import backtest_strat
from helpers import resume_backtest, performance_plot, annual_alpha_plot, price_to_perf, correlation, pred_to_perf

# %%
price, bench_price, df_X = get_price_data()
daily_returns = price.pct_change().shift(1)

# %%
fig, ax = plt.subplots(figsize=(16,6))
data_plot = (pd.concat([price, bench_price.rename('SPI')], axis=1).pct_change() + 1).cumprod().rolling(20).mean()
sns.lineplot(data=np.log(data_plot), dashes=False)
plt.show()

# %%
# models_list = ['MLP', 'ConvNet', 'LSTM']
# models_list = ['MLP', 'ConvNet']
models_list = ['MLP']
df_pred_dict = {}
df_prob_dict = {}

threshold = 0.8
batch_size = 10
verbose = 2
training_window = 5
nb_epochs_first = 150
nb_epochs = 150
rebalance_freq = 'W-FRI'
input_period_days = 15
input_period_weeks = 8
eta = 5e-4

if rebalance_freq == 'M':
    input_period = input_period_weeks
else:
    input_period = input_period_days

for i, model_name in enumerate(models_list):
    df_pred_dict[model_name], \
    df_prob_dict[model_name] = backtest_strat(df_input_all=df_X, price=price, rebalance_freq=rebalance_freq, 
                                              model_name=model_name, nb_epochs=nb_epochs, 
                                              nb_epochs_first=nb_epochs_first, input_period=input_period, 
                                              batch_size=batch_size, verbose=verbose, 
                                              training_window=training_window, threshold=threshold, eta=eta)

    if i == 0:
        df_prob_dict['Ensemble'] = df_prob_dict[model_name].copy()
    else:
        df_prob_dict['Ensemble'] += df_prob_dict[model_name]

df_prob_dict['Ensemble'] /= len(models_list)
df_pred_dict['Ensemble'] = pd.DataFrame().reindex_like(df_prob_dict['Ensemble']).fillna(0)
cols = df_pred_dict['Ensemble'].columns
for k in range(0, len(df_pred_dict['Ensemble'])):
    if k == 0:
        pred_index = df_prob_dict['Ensemble'].iloc[k].argmax()
        df_pred_dict['Ensemble'].iloc[k][cols[pred_index]] = 1
    else:
        out = df_prob_dict['Ensemble'].iloc[k].max()
        pred_index = df_prob_dict['Ensemble'].iloc[k].argmax()
        if out > threshold:
            df_pred_dict['Ensemble'].iloc[k][cols[pred_index]] = 1
        else:
            df_pred_dict['Ensemble'].iloc[k] = df_pred_dict['Ensemble'].iloc[k-1]
# Out:
# Backtesting model MLP
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 1 loss : 15.2182 accuracy : 52.34 %
# epoch 6 loss : 14.6266 accuracy : 52.34 %
# epoch 11 loss : 14.596 accuracy : 54.47 %
# epoch 16 loss : 13.684 accuracy : 57.02 %
# epoch 21 loss : 13.9701 accuracy : 62.98 %
# epoch 26 loss : 13.1364 accuracy : 66.81 %
# epoch 31 loss : 13.176 accuracy : 68.94 %
# epoch 36 loss : 12.3026 accuracy : 69.36 %
# epoch 41 loss : 12.3473 accuracy : 69.79 %
# epoch 46 loss : 11.7108 accuracy : 74.04 %
# epoch 51 loss : 11.3088 accuracy : 73.19 %
# epoch 56 loss : 10.501 accuracy : 76.17 %
# epoch 61 loss : 10.151 accuracy : 80.0 %
# epoch 66 loss : 10.4066 accuracy : 79.15 %
# epoch 71 loss : 10.2462 accuracy : 79.15 %
# epoch 56 loss : 4.5108 accuracy : 95.76 %
# epoch 61 loss : 4.7089 accuracy : 95.34 %
# epoch 66 loss : 5.2411 accuracy : 95.76 %
# epoch 71 loss : 4.6525 accuracy : 96.19 %
# epoch 76 loss : 4.7052 accuracy : 95.76 %
# epoch 81 loss : 3.6606 accuracy : 95.34 %
# epoch 86 loss : 4.1084 accuracy : 96.61 %
# epoch 91 loss : 4.5162 accuracy : 95.76 %
# epoch 96 loss : 4.5427 accuracy : 95.34 %
#  15%|█▌        | 6/40 [00:57<05:22,  9.49s/it]
# epoch 1 loss : 11.9705 accuracy : 87.29 %
# epoch 6 loss : 8.1797 accuracy : 87.29 %
# epoch 11 loss : 6.384 accuracy : 89.83 %
# epoch 16 loss : 6.3538 accuracy : 89.83 %
# epoch 21 loss : 6.4774 accuracy : 89.83 %
# epoch 26 loss : 6.6002 accuracy : 89.83 %
# epoch 31 loss : 6.0314 accuracy : 91.1 %
# epoch 36 loss : 5.791 accuracy : 90.68 %
# epoch 41 loss : 5.8694 accuracy : 91.1 %
# epoch 46 loss : 5.262 accuracy : 91.95 %
# epoch 51 loss : 5.328 accuracy : 91.53 %
# epoch 56 loss : 5.2822 accuracy : 91.53 %
# epoch 61 loss : 5.6804 accuracy : 93.64 %
# epoch 66 loss : 5.6613 accuracy : 91.95 %
# epoch 71 loss : 5.548 accuracy : 93.22 %
# epoch 76 loss : 5.1256 accuracy : 91.1 %
# epoch 81 loss : 6.8398 accuracy : 89.83 %
# epoch 86 loss : 13.2263 accuracy : 78.81 %
# epoch 91 loss : 9.1429 accuracy : 83.05 %
# epoch 96 loss : 9.1792 accuracy : 83.47 %
#  18%|█▊        | 7/40 [01:05<05:01,  9.14s/it]
# epoch 1 loss : 16.2958 accuracy : 79.57 %
# epoch 6 loss : 8.4258 accuracy : 84.26 %
# epoch 11 loss : 7.003 accuracy : 85.53 %
# epoch 16 loss : 6.7705 accuracy : 86.38 %
# epoch 21 loss : 6.8474 accuracy : 86.38 %
# epoch 26 loss : 6.1378 accuracy : 89.79 %
# epoch 31 loss : 6.3716 accuracy : 88.94 %
# epoch 36 loss : 6.7823 accuracy : 88.94 %
# epoch 41 loss : 6.547 accuracy : 88.09 %
# epoch 46 loss : 6.6816 accuracy : 87.23 %
# epoch 51 loss : 6.1533 accuracy : 88.51 %
# epoch 56 loss : 6.0897 accuracy : 89.79 %
# epoch 61 loss : 5.4401 accuracy : 89.79 %
# epoch 66 loss : 6.0435 accuracy : 89.79 %
# epoch 71 loss : 5.4262 accuracy : 88.94 %
# epoch 76 loss : 5.7684 accuracy : 88.94 %
# epoch 81 loss : 6.6445 accuracy : 88.51 %
# epoch 86 loss : 6.4524 accuracy : 88.51 %
# epoch 91 loss : 6.731 accuracy : 89.79 %
# epoch 96 loss : 6.3751 accuracy : 89.79 %
#  20%|██        | 8/40 [01:14<04:49,  9.05s/it]
# epoch 1 loss : 14.2513 accuracy : 78.72 %
# epoch 6 loss : 8.2926 accuracy : 81.7 %
# epoch 11 loss : 8.4684 accuracy : 83.4 %
# epoch 46 loss : 918.9048 accuracy : 43.64 %
# epoch 51 loss : 900.134 accuracy : 45.34 %
# epoch 56 loss : 866.6115 accuracy : 45.76 %
# epoch 61 loss : 874.4324 accuracy : 46.61 %
# epoch 66 loss : 950.3885 accuracy : 46.19 %
# epoch 71 loss : 875.7195 accuracy : 45.34 %
# epoch 76 loss : 887.6806 accuracy : 45.76 %
# epoch 81 loss : 906.6088 accuracy : 46.19 %
# epoch 86 loss : 948.466 accuracy : 46.61 %
# epoch 91 loss : 900.1429 accuracy : 46.19 %
# epoch 96 loss : 900.5259 accuracy : 46.19 %
#  35%|███▌      | 14/40 [02:06<03:45,  8.68s/it]
# epoch 1 loss : 797.9825 accuracy : 49.15 %
# epoch 6 loss : 928.7779 accuracy : 49.15 %
# epoch 11 loss : 894.1016 accuracy : 47.03 %
# epoch 16 loss : 868.2313 accuracy : 48.31 %
# epoch 21 loss : 914.2582 accuracy : 48.31 %
# epoch 26 loss : 829.7635 accuracy : 48.73 %
# epoch 31 loss : 882.7433 accuracy : 48.31 %
# epoch 36 loss : 808.4566 accuracy : 48.73 %
# epoch 41 loss : 917.0665 accuracy : 48.31 %
# epoch 46 loss : 816.4432 accuracy : 48.31 %
# epoch 51 loss : 869.2201 accuracy : 47.88 %
#  35%|███▌      | 14/40 [02:10<04:03,  9.35s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-80dc00d0874f> in <module>
#      23 for i, model_name in enumerate(models_list):
#      24     df_pred_dict[model_name], \
# ---> 25     df_prob_dict[model_name] = backtest_strat(df_input_all=df_X, price=price, rebalance_freq=rebalance_freq,
#      26                                               model_name=model_name, nb_epochs=nb_epochs,
#      27                                               nb_epochs_first=nb_epochs_first, input_period=input_period,
#
# ~/Documents/bcv_project/BCVS/SW/size/backtest.py in backtest_strat(df_input_all, price, rebalance_freq, model_name, nb_epochs, nb_epochs_first, input_period, training_window, batch_size, verbose, threshold, eta)
#     137         # Train the model
#     138
# --> 139         train(model, X_train, y_train, nb_epochs_all, X_test, y_test, i, eta=eta, batch_size=batch_size, verbose=verbose)
#     140
#     141         # Get predictions
#
# ~/Documents/bcv_project/BCVS/SW/size/train_test.py in train(model, X_train, y_train, nb_epochs, X_test, y_test, i, eta, weight_decay, batch_size, verbose)
#      70             test_accu_list.append(test_accu)
#      71
# ---> 72             train_loss = output_to_loss(model, X_train, y_train).detach().numpy()
#      73             train_loss_list.append(train_loss)
#      74             test_loss = output_to_loss(model, X_test, y_test).detach().numpy()
#
# ~/Documents/bcv_project/BCVS/SW/size/train_test.py in output_to_loss(model, X, y)
#      24     criterion = nn.BCELoss()
#      25     for b in range(0, X.size(0)):
# ---> 26         output = model(X.narrow(0, b, 1))
#      27         loss += criterion(output, y.narrow(0, b, 1))
#      28
#
# ~/Documents/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/bcv_project/BCVS/SW/size/models.py in forward(self, x)
#      16     def forward(self, x):
#      17         x = x.flatten(start_dim=1)
# ---> 18         x = self.relu(self.drop(self.fc1(x)))
#      19         x = self.relu(self.drop(self.fc2(x)))
#      20         x = self.fc3(x)
#
# ~/Documents/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Documents/anaconda3/lib/python3.8/site-packages/torch/nn/modules/dropout.py in forward(self, input)
#      56
#      57     def forward(self, input: Tensor) -> Tensor:
# ---> 58         return F.dropout(input, self.p, self.training, self.inplace)
#      59
#      60
#
# ~/Documents/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py in dropout(input, p, training, inplace)
#    1167     if p < 0.0 or p > 1.0:
#    1168         raise ValueError("dropout probability has to be between 0 and 1, " "but got {}".format(p))
# -> 1169     return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1170
#    1171
#
# ~/Documents/anaconda3/lib/python3.8/site-packages/torch/_VF.py in __getattr__(self, attr)
#      23         self.vf = torch._C._VariableFunctions
#      24
# ---> 25     def __getattr__(self, attr):
#      26         return getattr(self.vf, attr)
#      27
#
# KeyboardInterrupt:

# %%
df_resume = resume_backtest(df_pred_dict, bench_price, price)
daily_returns = price.pct_change().shift(1)
perf_bench = price_to_perf(bench_price.loc[df_pred_dict['Ensemble'].index[0]:df_pred_dict['Ensemble'].index[-1]], log=False)
performance_plot(df_pred_dict, daily_returns, bench_price, log=True)
annual_alpha_plot(perf_bench, df_pred_dict['Ensemble'], daily_returns)
display(df_resume)
# Out:
#                Gross avg. annual return (%)  Net avg. annual return (%)  Avg. annual vol. (%)  Avg Sharpe ratio  Max. Drawdown (%)  Turnover
# Benchmark SPI                          7.13                        7.13                 17.43              0.41              44.52         0
# MLP                                    5.81                        4.84                 16.92              0.29              50.14       165
# ConvNet                               10.26                        7.35                 16.55              0.44              42.67       470
# LSTM                                   7.20                        4.30                 17.26              0.25              52.05       483
# Ensemble                               9.12                        7.86                 16.91              0.46              49.53       202

# %%
df = pd.DataFrame(index=models_list, columns=models_list)
for comb in itertools.product(models_list, repeat=2):
    model1 = comb[0]
    model2 = comb[1]
    df.loc[model1][model2] = correlation(df_pred_dict[model1], df_pred_dict[model2])
df = df.astype(float)
df.round(2)
# Out:
#           MLP  ConvNet  LSTM
# MLP      1.00     0.45  0.46
# ConvNet  0.45     1.00  0.39
# LSTM     0.46     0.39  1.00

# %%
df_results = pd.DataFrame()

for model_name in df_pred_dict:
    L = len(df_pred_dict[model_name])
    df_results = pd.concat([df_results, (df_pred_dict[model_name].sum(axis=0) / L).rename(model_name)], axis=1)

returns = price.pct_change().shift(1).resample(rebalance_freq).agg(lambda x: (x + 1).prod() - 1)
best_pred = returns.rank(axis=1).replace({1: 0., 2: 0., 3: 1.}).shift(-1).loc[df_pred_dict[model_name].index[0]:df_pred_dict[model_name].index[-1]]

df_results = pd.concat([df_results, (best_pred.sum(axis=0) / L).rename('Best_prediction')], axis=1)
df_results = df_results.reset_index()
df_results = df_results.melt(id_vars='index', var_name='strategie', value_name='frequence')

fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(data=df_results, x='index', y='frequence', hue='strategie')
ax.set_xlabel(None)
ax.set_ylabel(None)
plt.show()

# %%
df_pred = df_pred_dict['Ensemble']
first_date = '2008-01-01'
last_date = '2010-01-01'
#first_date = df_pred.index[0]
#last_date = df_pred.index[-1]
daily_ret = daily_returns.loc[first_date:last_date]
daily_perf = np.log((daily_ret + 1).cumprod())
df_pred_daily = df_pred.reindex(daily_ret.index, method='ffill').shift(1)
daily_perf_pred = daily_perf.mul(df_pred_daily).replace(0., np.nan)
indice_perf_pred = pd.Series(index=daily_perf_pred.index, dtype='float64', name='Prediction')
for idx, row in daily_perf_pred[1:].iterrows():
    indice_perf_pred.loc[idx] = row[~row.isna()].item()

fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(data=daily_perf.rolling(10).mean(), dashes=True, lw=1, zorder=1)
ax.plot(indice_perf_pred.rolling(10).mean(), label='Prediction', c='r', lw=2, zorder=2)
plt.legend()
plt.show()
